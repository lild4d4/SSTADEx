# %%
import sys
from sstadex import Transistor
import numpy as np
sys.path.insert(0, '../../..')

# %%
from gmid import mosplot

# %% [markdown]
# # IHP

# %%
obj = mosplot.LookupTableGenerator(
    description="freepdk ihp ngspice",
    simulator="ngspice",
    model_paths=[
        "/opt/pdks/ihp-sg13g2/libs.tech/ngspice/models/cornerMOShv.lib mos_tt",
        ],
    model_names={
            "nmos": "sg13_hv_nmos",
            "pmos": "sg13_hv_pmos",
    },
    model_display = "n.xm1.n",
    vsb=(0, 0.1, 0.1),
    vgs=(0, 3.3, 0.01),
    vds=(0, 3.3, 0.01),
    width=5e-6,
    lengths=[0.4e-6, 0.8e-6, 1.6e-6, 3.2e-6, 6.4e-6],
)
obj.pdk = "ihp"
obj.build("../../LUTs/ihp_lut_hv.npy")
# Out:
# holi
# Generating lookup table for NMOS
# ---------------------------------------------------
# ----- This is the netlist that gets simulated -----
# ---------------------------------------------------
# * Lookup Table Generation *
# .lib '/opt/pdks/ihp-sg13g2/libs.tech/ngspice/models/cornerMOShv.lib mos_tt'
# VGS NG 0 DC=0
# VBS NB 0 DC=0
# VDS ND 0 DC=0
# XM1 ND NG 0 NB sg13_hv_nmos L=0.4u W=5.0u
#
# .options TEMP = 27
# .options TNOM = 27
# .control
# pre_osdi /opt/pdks/ihp-sg13g2/libs.tech/ngspice/openvaf/psp103_nqs.osdi
# save i(vds)
# save @n.xm1.nsg13_hv_nmos[vth]
# save @n.xm1.nsg13_hv_nmos[vdsat]
# save @n.xm1.nsg13_hv_nmos[gm]
# save @n.xm1.nsg13_hv_nmos[gmbs]
# save @n.xm1.nsg13_hv_nmos[gds]
# save @n.xm1.nsg13_hv_nmos[cgg]
# save @n.xm1.nsg13_hv_nmos[cgs]
# save @n.xm1.nsg13_hv_nmos[cbg]
# save @n.xm1.nsg13_hv_nmos[cgd]
# save @n.xm1.nsg13_hv_nmos[cdd]
# dc VDS 0.0 3.3 0.01 VGS 0.0 3.3 0.01
# let i_vds = abs(i(vds))
# write /tmp/tmp_hrqzfig all
# .endc
# .end
# ...

# %%
obj = mosplot.LookupTableGenerator(
    description="freepdk ihp ngspice",
    simulator="ngspice",
    model_paths=[
        "/opt/pdks/ihp-sg13g2/libs.tech/ngspice/models/cornerMOShv.lib mos_tt",
        ],
    model_names={
            "nmos": "sg13_hv_nmos",
            "pmos": "sg13_hv_pmos",
    },
    model_display = "n.xm1.n",
    vsb=(0, 0.1, 0.1),
    vgs=(0, 3.3, 0.01),
    vds=(0, 3.3, 0.01),
    width=20e-6,
    lengths=[0.4e-6, 0.45e-6, 0.8e-6, 1.6e-6, 3.2e-6, 6.4e-6],
)
obj.pdk = "ihp"
obj.build("../../LUTs/ihp_lut_hv_20w.npy")
# Out:
# holi
# Generating lookup table for NMOS
# ---------------------------------------------------
# ----- This is the netlist that gets simulated -----
# ---------------------------------------------------
# * Lookup Table Generation *
# .lib '/opt/pdks/ihp-sg13g2/libs.tech/ngspice/models/cornerMOShv.lib mos_tt'
# VGS NG 0 DC=0
# VBS NB 0 DC=0
# VDS ND 0 DC=0
# XM1 ND NG 0 NB sg13_hv_nmos L=0.4u W=20.0u
#
# .options TEMP = 27
# .options TNOM = 27
# .control
# pre_osdi /opt/pdks/ihp-sg13g2/libs.tech/ngspice/openvaf/psp103_nqs.osdi
# save i(vds)
# save @n.xm1.nsg13_hv_nmos[vth]
# save @n.xm1.nsg13_hv_nmos[vdsat]
# save @n.xm1.nsg13_hv_nmos[gm]
# save @n.xm1.nsg13_hv_nmos[gmbs]
# save @n.xm1.nsg13_hv_nmos[gds]
# save @n.xm1.nsg13_hv_nmos[cgg]
# save @n.xm1.nsg13_hv_nmos[cgs]
# save @n.xm1.nsg13_hv_nmos[cbg]
# save @n.xm1.nsg13_hv_nmos[cgd]
# save @n.xm1.nsg13_hv_nmos[cdd]
# save @n.xm1.nsg13_hv_nmos[cds]
# dc VDS 0.0 3.3 0.01 VGS 0.0 3.3 0.01
# let i_vds = abs(i(vds))
# ...

# %%
obj = mosplot.LookupTableGenerator(
    description="freepdk ihp ngspice",
    simulator="ngspice",
    model_paths=[
        "/opt/pdks/ihp-sg13g2/libs.tech/ngspice/models/cornerMOShv.lib mos_tt",
        ],
    model_names={
            "nmos": "sg13_hv_nmos",
            "pmos": "sg13_hv_pmos",
    },
    model_display = "n.xm1.n",
    vsb=(0, 0.1, 0.1),
    vgs=(0, 3.3, 0.01),
    vds=(0, 3.3, 0.01),
    width=1e-6,
    lengths=[0.4e-6, 0.8e-6, 1.6e-6, 3.2e-6, 6.4e-6],
)
obj.pdk = "ihp"
obj.build("../../LUTs/ihp_lut_hv_1w.npy")
# Out:
# holi
# Generating lookup table for NMOS
# ---------------------------------------------------
# ----- This is the netlist that gets simulated -----
# ---------------------------------------------------
# * Lookup Table Generation *
# .lib '/opt/pdks/ihp-sg13g2/libs.tech/ngspice/models/cornerMOShv.lib mos_tt'
# VGS NG 0 DC=0
# VBS NB 0 DC=0
# VDS ND 0 DC=0
# XM1 ND NG 0 NB sg13_hv_nmos L=0.4u W=1.0u
#
# .options TEMP = 27
# .options TNOM = 27
# .control
# pre_osdi /opt/pdks/ihp-sg13g2/libs.tech/ngspice/openvaf/psp103_nqs.osdi
# save i(vds)
# save @n.xm1.nsg13_hv_nmos[vth]
# save @n.xm1.nsg13_hv_nmos[vdsat]
# save @n.xm1.nsg13_hv_nmos[gm]
# save @n.xm1.nsg13_hv_nmos[gmbs]
# save @n.xm1.nsg13_hv_nmos[gds]
# save @n.xm1.nsg13_hv_nmos[cgg]
# save @n.xm1.nsg13_hv_nmos[cgs]
# save @n.xm1.nsg13_hv_nmos[cbg]
# save @n.xm1.nsg13_hv_nmos[cgd]
# save @n.xm1.nsg13_hv_nmos[cdd]
# dc VDS 0.0 3.3 0.01 VGS 0.0 3.3 0.01
# let i_vds = abs(i(vds))
# write /tmp/tmpxjyhqs2q all
# .endc
# .end
# ...

# %%
obj = mosplot.LookupTableGenerator(
    description="freepdk ihp ngspice",
    simulator="ngspice",
    model_paths=[
        "/opt/pdks/ihp-sg13g2/libs.tech/ngspice/models/cornerMOSlv.lib mos_tt",
        ],
    model_names={
            "nmos": "sg13_lv_nmos",
            "pmos": "sg13_lv_pmos",
    },
    model_display = "n.xm1.n",
    vsb=(0, 0.1, 0.1),
    vgs=(0, 1.8, 0.01),
    vds=(0, 1.8, 0.01),
    width=20e-6,
    lengths=[0.4e-6, 0.8e-6, 1.6e-6, 3.2e-6, 6.4e-6],
)
obj.pdk = "ihp"
obj.build("../../LUTs/ihp_lut_lv_20w.npy")
# Out:
# holi
# Generating lookup table for NMOS
# ---------------------------------------------------
# ----- This is the netlist that gets simulated -----
# ---------------------------------------------------
# * Lookup Table Generation *
# .lib '/opt/pdks/ihp-sg13g2/libs.tech/ngspice/models/cornerMOSlv.lib mos_tt'
# VGS NG 0 DC=0
# VBS NB 0 DC=0
# VDS ND 0 DC=0
# XM1 ND NG 0 NB sg13_lv_nmos L=0.4u W=20.0u
#
# .options TEMP = 27
# .options TNOM = 27
# .control
# pre_osdi /opt/pdks/ihp-sg13g2/libs.tech/ngspice/openvaf/psp103_nqs.osdi
# save i(vds)
# save @n.xm1.nsg13_lv_nmos[vth]
# save @n.xm1.nsg13_lv_nmos[vdsat]
# save @n.xm1.nsg13_lv_nmos[gm]
# save @n.xm1.nsg13_lv_nmos[gmbs]
# save @n.xm1.nsg13_lv_nmos[gds]
# save @n.xm1.nsg13_lv_nmos[cgg]
# save @n.xm1.nsg13_lv_nmos[cgs]
# save @n.xm1.nsg13_lv_nmos[cbg]
# save @n.xm1.nsg13_lv_nmos[cgd]
# save @n.xm1.nsg13_lv_nmos[cdd]
# save @n.xm1.nsg13_lv_nmos[cds]
# dc VDS 0.0 1.8 0.01 VGS 0.0 1.8 0.01
# let i_vds = abs(i(vds))
# ...

# %%
obj = mosplot.LookupTableGenerator(
    description="freepdk ihp ngspice",
    simulator="ngspice",
    model_paths=[
        "/opt/pdks/ihp-sg13g2/libs.tech/ngspice/models/cornerMOSlv.lib mos_tt",
        ],
    model_names={
            "nmos": "sg13_lv_nmos",
            "pmos": "sg13_lv_pmos",
    },
    model_display = "n.xm1.n",
    vsb=(0, 0.1, 0.1),
    vgs=(0, 1.8, 0.01),
    vds=(0, 1.8, 0.01),
    width=10e-6,
    lengths=[0.4e-6, 0.8e-6, 1.6e-6, 3.2e-6, 6.4e-6],
)
obj.pdk = "ihp"
obj.build("../../LUTs/ihp_lut_lv_10w.npy")
# Out:
# holi
# Generating lookup table for NMOS
# ---------------------------------------------------
# ----- This is the netlist that gets simulated -----
# ---------------------------------------------------
# * Lookup Table Generation *
# .lib '/opt/pdks/ihp-sg13g2/libs.tech/ngspice/models/cornerMOSlv.lib mos_tt'
# VGS NG 0 DC=0
# VBS NB 0 DC=0
# VDS ND 0 DC=0
# XM1 ND NG 0 NB sg13_lv_nmos L=0.4u W=10.0u
#
# .options TEMP = 27
# .options TNOM = 27
# .control
# pre_osdi /opt/pdks/ihp-sg13g2/libs.tech/ngspice/openvaf/psp103_nqs.osdi
# save i(vds)
# save @n.xm1.nsg13_lv_nmos[vth]
# save @n.xm1.nsg13_lv_nmos[vdsat]
# save @n.xm1.nsg13_lv_nmos[gm]
# save @n.xm1.nsg13_lv_nmos[gmbs]
# save @n.xm1.nsg13_lv_nmos[gds]
# save @n.xm1.nsg13_lv_nmos[cgg]
# save @n.xm1.nsg13_lv_nmos[cgs]
# save @n.xm1.nsg13_lv_nmos[cbg]
# save @n.xm1.nsg13_lv_nmos[cgd]
# save @n.xm1.nsg13_lv_nmos[cdd]
# save @n.xm1.nsg13_lv_nmos[cds]
# dc VDS 0.0 1.8 0.01 VGS 0.0 1.8 0.01
# let i_vds = abs(i(vds))
# ...

# %%
obj = mosplot.LookupTableGenerator(
    description="freepdk ihp ngspice",
    simulator="ngspice",
    model_paths=[
        "/opt/pdks/ihp-sg13g2/libs.tech/ngspice/models/cornerMOSlv.lib mos_tt",
        ],
    model_names={
            "nmos": "sg13_lv_nmos",
            "pmos": "sg13_lv_nmos",
    },
    model_display = "n.xm1.n",
    vsb=(0, 0.1, 0.1),
    vgs=(0, 1.8, 0.01),
    vds=(0, 1.8, 0.01),
    width=20e-6,
    lengths=[0.4e-6, 0.8e-6, 1.6e-6, 3.2e-6, 6.4e-6],
)
obj.pdk="ihp"
obj.build("../../LUTs/IHP_LUT_lv.npy")
# Out:
# holi
# Generating lookup table for NMOS
# ---------------------------------------------------
# ----- This is the netlist that gets simulated -----
# ---------------------------------------------------
# * Lookup Table Generation *
# .lib '/opt/pdks/ihp-sg13g2/libs.tech/ngspice/models/cornerMOSlv.lib mos_tt'
# VGS NG 0 DC=0
# VBS NB 0 DC=0
# VDS ND 0 DC=0
# XM1 ND NG 0 NB sg13_lv_nmos L=0.4u W=20.0u
#
# .options TEMP = 27
# .options TNOM = 27
# .control
# pre_osdi /opt/pdks/ihp-sg13g2/libs.tech/ngspice/openvaf/psp103_nqs.osdi
# save i(vds)
# save @n.xm1.nsg13_lv_nmos[vth]
# save @n.xm1.nsg13_lv_nmos[vdsat]
# save @n.xm1.nsg13_lv_nmos[gm]
# save @n.xm1.nsg13_lv_nmos[gmbs]
# save @n.xm1.nsg13_lv_nmos[gds]
# save @n.xm1.nsg13_lv_nmos[cgg]
# save @n.xm1.nsg13_lv_nmos[cgs]
# save @n.xm1.nsg13_lv_nmos[cbg]
# save @n.xm1.nsg13_lv_nmos[cgd]
# save @n.xm1.nsg13_lv_nmos[cdd]
# save @n.xm1.nsg13_lv_nmos[cds]
# dc VDS 0.0 1.8 0.01 VGS 0.0 1.8 0.01
# let i_vds = abs(i(vds))
# ...

# %%
lengths = [0.4e-06, 0.8e-06, 1.6e-06, 3.2e-06, 6.4e-6]
vgs_explore = np.linspace(0.1, 1.3, 40)

ihp_transistor = Transistor(
            "../../LUTs/IHP_LUT_lv.npy",
            "nmos",
            0,
            0.9,
            (0, 1.8, 0.01),
            [0.4e-06, 0.8e-06, 1.6e-06, 3.2e-06, 6.4e-6],
            ['length', 'vgs'],
            [
                lengths,
                vgs_explore,
            ],
        )
# Out:
# length
# vgs
# 0

# %% [markdown]
# # GF

# %%
obj = mosplot.LookupTableGenerator(
    description="freepdk ihp ngspice",
    simulator="ngspice",
    raw_spice = ".include /opt/pdks/gf180mcuD/libs.tech/ngspice/design.ngspice",
    model_paths=[
        "/opt/pdks/gf180mcuD/libs.tech/ngspice/sm141064.ngspice typical",
        ],
    model_names={
            "nmos": "nfet_03v3",
            "pmos": "pfet_03v3",
    },
    model_display = "m.xm1.m0",
    vsb=(0, 0.1, 0.1),
    vgs=(0, 3.3, 0.01),
    vds=(0, 3.3, 0.01),
    width=20e-6,
    lengths=[0.4e-6, 0.8e-6, 1.6e-6, 3.2e-6, 6.4e-6],
)
obj.pdk = "gf"
obj.build("../../LUTs/gf_LUT_03v3.npy")
# Out:
# holi
# Generating lookup table for NMOS
# ---------------------------------------------------
# ----- This is the netlist that gets simulated -----
# ---------------------------------------------------
# * Lookup Table Generation *
# .lib '/opt/pdks/gf180mcuD/libs.tech/ngspice/sm141064.ngspice typical'
# VGS NG 0 DC=0
# VBS NB 0 DC=0
# VDS ND 0 DC=0
# XM1 ND NG 0 NB nfet_03v3 L=0.4u W=20.0u
# .include /opt/pdks/gf180mcuD/libs.tech/ngspice/design.ngspice
# .options TEMP = 27
# .options TNOM = 27
# .control
# pre_osdi /opt/pdks/ihp-sg13g2/libs.tech/ngspice/openvaf/psp103_nqs.osdi
# save i(vds)
# save @m.xm1.m0[vth]
# save @m.xm1.m0[vdsat]
# save @m.xm1.m0[gm]
# save @m.xm1.m0[gmbs]
# save @m.xm1.m0[gds]
# save @m.xm1.m0[cgg]
# save @m.xm1.m0[cgs]
# save @m.xm1.m0[cbg]
# save @m.xm1.m0[cgd]
# save @m.xm1.m0[cdd]
# dc VDS 0.0 3.3 0.01 VGS 0.0 3.3 0.01
# let i_vds = abs(i(vds))
# write /tmp/tmpnmpkwoeq all
# .endc
# .end
# ---------------------------------------------------
#
# ...

# %%
lengths = [0.4e-06, 0.8e-06, 1.6e-06, 3.2e-06, 6.4e-6]
vgs_explore = np.linspace(0.1, 1.3, 40)

ihp_transistor = Transistor(
            "../../LUTs/gf_LUT_03v3.npy",
            "nmos",
            0,
            0.9,
            (0, 1.8, 0.01),
            [0.4e-06, 0.8e-06, 1.6e-06, 3.2e-06, 6.4e-6],
            ['length', 'vgs'],
            [
                lengths,
                vgs_explore,
            ],
        )
# Out:
# length
# vgs
# 0

# %% [markdown]
# # SKY

# %%
obj = mosplot.LookupTableGenerator(
    description="freepdk ihp ngspice",
    simulator="ngspice",
    model_paths=[
        "/opt/pdks/sky130A/libs.tech/ngspice/sky130.lib.spice tt",
        ],
    model_names={
            "nmos": "sky130_fd_pr__nfet_01v8",
            "pmos": "sky130_fd_pr__pfet_01v8",
    },
    model_display = "m.xm1.m",
    vsb=(0, 0.1, 0.1),
    vgs=(0, 3.3, 0.01),
    vds=(0, 3.3, 0.01),
    width=20e-6,
    lengths=[0.5e-6, 0.8e-6, 1.6e-6, 3.2e-6, 6.4e-6],
)
obj.pdk = "ihp"
obj.build("../../LUTs/sky130A_LUT_01v8.npy")
# Out:
# holi
# Generating lookup table for NMOS
# ---------------------------------------------------
# ----- This is the netlist that gets simulated -----
# ---------------------------------------------------
# * Lookup Table Generation *
# .lib '/opt/pdks/sky130A/libs.tech/ngspice/sky130.lib.spice tt'
# VGS NG 0 DC=0
# VBS NB 0 DC=0
# VDS ND 0 DC=0
# XM1 ND NG 0 NB sky130_fd_pr__nfet_01v8 L=0.5 W=20.0
#
# .options TEMP = 27
# .options TNOM = 27
# .control
# pre_osdi /opt/pdks/ihp-sg13g2/libs.tech/ngspice/openvaf/psp103_nqs.osdi
# save i(vds)
# save @m.xm1.msky130_fd_pr__nfet_01v8[vth]
# save @m.xm1.msky130_fd_pr__nfet_01v8[vdsat]
# save @m.xm1.msky130_fd_pr__nfet_01v8[gm]
# save @m.xm1.msky130_fd_pr__nfet_01v8[gmbs]
# save @m.xm1.msky130_fd_pr__nfet_01v8[gds]
# save @m.xm1.msky130_fd_pr__nfet_01v8[cgg]
# save @m.xm1.msky130_fd_pr__nfet_01v8[cgs]
# save @m.xm1.msky130_fd_pr__nfet_01v8[cbg]
# save @m.xm1.msky130_fd_pr__nfet_01v8[cgd]
# save @m.xm1.msky130_fd_pr__nfet_01v8[cdd]
# ...
